# %%
import numpy as np
import sys
import os
sys.path.append(os.path.abspath('..'))
from scripts import nodes as n

# %%
n1 = n.nodes(0, 0, 0)
n2 = n.nodes(1, 0, 0)
n3 = n.nodes(0, 1, 0)
n4 = n.nodes(0, 0, 1)
n5 = n.nodes(1, 1, 0)
n6 = n.nodes(1, 0, 1)

n_list = [n1, n2, n3, n4, n5, n6]
n.plot_nodes(n_list)

# %%
e1 = n.element(n1, n2)
e2 = n.element(n2, n3)
e3 = n.element(n3, n4)
e4 = n.element(n4, n1)
elements = [e1, e2, e3, e4]

n.plot_elements(elements)
