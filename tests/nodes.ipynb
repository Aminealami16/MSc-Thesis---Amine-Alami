# %%
import numpy as np
import sys
import os
sys.path.append(os.path.abspath('..'))
from scripts import nodes as n

# %%
n1 = n.nodes(0, 0, 0)
n2 = n.nodes(237.5, 45, 0)
n3 =  n.nodes(237.5,-45, 0)
n4 = n.nodes(195, 195* (45/237.5), 0)
n5 = n.nodes(195, -195* (45/237.5), 0)

n_list = [n1, n2, n3, n4, n5]
n.plot_nodes(n_list)

# %%
e1 = n.elements(n1, n5)
e2 = n.elements(n1, n4)
e3 = n.elements(n4, n5)
e4 = n.elements(n5, n3)
e5 = n.elements(n4, n2)
e6 = n.elements(n2, n3)
elements = [e1, e2, e3, e4, e5, e6]

n.plot_elements(elements)
